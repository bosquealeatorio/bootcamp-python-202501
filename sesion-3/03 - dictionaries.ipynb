# %% [markdown]
# # Python Inmersion Bootcamp - Basic Structures
# Manuel Montoya Gamio | Machine Learning Engineer

# %% [markdown]
# # Dictionaries

# %% [markdown]
# <img src='https://s.wsj.net/public/resources/images/BN-QP214_bkrvwo_OR_20161102154653.jpg'>

# %%
meta_list = [['Mark Zuckerberg', 'Eduardo Saverin'], 'www.meta.com', 2.9]

# %%
meta_list[0]
# Out:
# ['Mark Zuckerberg', 'Eduardo Saverin']

# %%
meta_dict = {"founders": ["Mark Zuckerberg", "Eduardo Saverin"],
             "url": "www.facebook.com",
             "number_of_users": 2.9}

# %%
meta_dict["url"]
# Out:
# 'www.facebook.com'

# %%
meta_dict["founders"]
# Out:
# ['Mark Zuckerberg', 'Eduardo Saverin']

# %% [markdown]
# are dictionaries mutable?

# %%
meta_dict["url"] = "wwww.meta.com"

# %%
meta_dict
# Out:
# {'founders': ['Mark Zuckerberg', 'Eduardo Saverin'],
#  'url': 'wwww.meta.com',
#  'number_of_users': 2.9}

# %% [markdown]
# adding/replacing elements

# %%
meta_dict["sister_companies"] = ["whatsapp", "instagram"]

# %%
meta_dict
# Out:
# {'founders': ['Mark Zuckerberg', 'Eduardo Saverin'],
#  'url': 'wwww.meta.com',
#  'number_of_users': 2.9,
#  'sister_companies': ['whatsapp', 'instagram']}

# %% [markdown]
# deleting an element?

# %%
del(meta_dict["number_of_users"])

# %%
meta_dict
# Out:
# {'founders': ['Mark Zuckerberg', 'Eduardo Saverin'],
#  'url': 'wwww.meta.com',
#  'sister_companies': ['whatsapp', 'instagram']}

# %% [markdown]
# accessing elements

# %%
meta_dict.get("founders")
# Out:
# ['Mark Zuckerberg', 'Eduardo Saverin']

# %%
meta_dict.get("fundadores")

# %%
type(meta_dict.get("fundadores"))
# Out:
# NoneType

# %%
meta_dict.get("fundadores", "vacio")
# Out:
# 'vacio'

# %%
meta_dict["fundadores"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 meta_dict["fundadores"]
#
# KeyError: 'fundadores'

# %% [markdown]
# ## Iterate over dictionaries

# %% [markdown]
# keys, values, items

# %%
file_counts = {
    'jpg': 100, 
    'png': 20, 
    'csv': 10, 
    'py': 25
}

file_counts
# Out:
# {'jpg': 100, 'png': 20, 'csv': 10, 'py': 25}

# %%
file_counts.keys()
# Out:
# dict_keys(['jpg', 'png', 'csv', 'py'])

# %%
file_counts.values()
# Out:
# dict_values([100, 20, 10, 25])

# %%
file_counts.items()
# Out:
# dict_items([('jpg', 100), ('png', 20), ('csv', 10), ('py', 25)])

# %%
for key, value in file_counts.items():
    print("key: ", key, "value:", value)
# Out:
# key:  jpg value: 100
# key:  png value: 20
# key:  csv value: 10
# key:  py value: 25

# %%
file_counts
# Out:
# {'jpg': 100, 'png': 20, 'csv': 10, 'py': 25}

# %%
"csv" in file_counts
# Out:
# True

# %%
100 in file_counts
# Out:
# False

# %%
100 in file_counts.values()
# Out:
# True

# %%
for _ in range(10):
    print("hola")
# Out:
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola

# %%
lista = [('jpg', 100), ('png', 20), ('csv', 10), ('py', 25)]

for extension, _ in lista:
    print(f".{extension}")
# Out:
# .jpg
# .png
# .csv
# .py

# %% [markdown]
# Write a function that recieves a text and returns a dictionary with the count of each letter

# %%
text = ""

def letter_counter(text):
    
    pass    
        
    return results_dict

# %%
[x**2 for x in range(10)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
{x: x**2 for x in range(10)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
dict_1 = {'jpg': 100, 'png': 20}
dict_2 = {'csv': 10, 'py': 25}

# %%
dict_1.update(dict_2)

# %%
dict_1
# Out:
# {'jpg': 100, 'png': 20, 'csv': 10, 'py': 25}

# %%
dict_2
# Out:
# {'csv': 10, 'py': 25}

# %%
dict_1 = {'jpg': 100, 'png': 20}
dict_2 = {'csv': 10, 'py': 25, 'png': 2000}

# %%
dict_1.update(dict_2)

# %%
dict_1["png"]
# Out:
# 2000

# %% [markdown]
# ## Sets

# %% [markdown]
# <img src='https://preview.redd.it/g6vhhhsht6b91.jpg?auto=webp&s=514dc3782f6f4c2c631035dbf4490cc7738f1eae' width='400' align='left'>

# %%
dict_foo = {'key1': 6, 'key2': 7, 'key3': 8}
type(dict_foo)
# Out:
# dict

# %%
dict_bar = {}
type(dict_bar)
# Out:
# dict

# %%
x = {'key1', 'key2', 'key3'}

# %%
type(x)
# Out:
# set

# %%
x = {'key1', 'key2', 'key3', 'key3', 'key2'}
x
# Out:
# {'key1', 'key2', 'key3'}

# %%
lista = ['key1', 'key2', 'key3', 'key3', 'key2']
list(set(lista))
# Out:
# ['key3', 'key1', 'key2']

# %%
lista_1 = [1, 2, 3, 4, 5, 6, 1, 1, 1, 1, 1, 1]
lista_2 = [4, 5, 6, 7, 8, 9]

# %%
[x for x in lista_1 if x in lista_2]
# Out:
# [4, 5, 6]

# %%
list(set(lista_1).intersection(set(lista_2)))
# Out:
# [4, 5, 6]

# %%
set_1 = set(lista_1)
set_2 = set(lista_2)

# %%
set_1.update(set_2)

# %%
set_1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# ## Explicit casting

# %%
cadena = 'abcde'
listas = ['a', 'b', 'c', 'd', 'e']
tuplas = ('a', 'b', 'c', 'd', 'e')
sets = {'a', 'b', 'c', 'd', 'e'}

# %%
list(cadena)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
tuple(sets)
# Out:
# ('b', 'd', 'e', 'a', 'c')

# %% [markdown]
# ## Exercises

# %% [markdown]
# The email_list function receives a dictionary, which contains domain names as keys, and a list of users as values. Fill in the blanks to generate a list that contains complete email addresses (e.g. diana.prince@gmail.com).

# %%
def email_list(domains):
    emails = []
    
    return emails
    
print(email_list({"avengers.com": ["anthony.stark", "thor.odinson", "steve.rodgers"], "dccomics.com": ["barbara.gordon", "bruce.wayne", "slade.wilson"], "xmen.com": ["jean.gray", "hank.mccoy"]}))

# %% [markdown]
# Write a function that returns the total price of all the groceries in a dictionary

# %%
def add_prices(basket):

    total = 0

    return round(total, 2)  


groceries = {"bananas": 1.56, "apples": 2.50, "oranges": 0.99, 
             "bread": 4.59, "coffee": 6.99, "milk": 3.39, 
             "eggs": 2.98, "cheese": 5.44}

# Should print 28.44
print(add_prices(groceries))

# %% [markdown]
# Use a dictionary to count the frequency of letters in the input string. Only letters should be counted, not blank spaces, numbers, or punctuation. Upper case should be considered the same as lower case. For example, count_letters("This is a sentence.") should return {'t': 2, 'h': 1, 'i': 2, 's': 3, 'a': 1, 'e': 3, 'n': 2, 'c': 1}.

# %%
def count_letters(text):
    
    result = {}

    return result

print(count_letters("AaBbCc"))
# Should be {'a': 2, 'b': 2, 'c': 2}

print(count_letters("Math is fun! 2+2=4"))
# Should be {'m': 1, 'a': 1, 't': 1, 'h': 1, 'i': 1, 's': 1, 'f': 1, 'u': 1, 'n': 1}

print(count_letters("This is a sentence."))
# Should be {'t': 2, 'h': 1, 'i': 2, 's': 3, 'a': 1, 'e': 3, 'n': 2, 'c': 1}

# %% [markdown]
# ## Challenge

# %% [markdown]
# The groups_per_user function receives a dictionary, which contains group names with the list of users. Users can belong to multiple groups. Fill in the blanks to return a dictionary with the users as keys and a list of their groups as values.

# %%
def groups_per_user(group_dictionary):

    return(user_groups)


# should return {'admin': ['local', 'public', 'administrator'], 'userA': ['local'], 'userB': ['public']}
print(groups_per_user({"local": ["admin", "userA"], "public":  ["admin", "userB"], "administrator": ["admin"] }))

# %% [markdown]
# The highlight_word function changes the given word in a sentence to its upper-case version.
#
# For example, highlight_word("Have a nice day", "nice") returns "Have a NICE day".
#
# BONUS: Can you write this function in just one line?

# %%
def highlight_word(sentence, word):
    return ''

#Should return "Have a NICE day"
print(highlight_word("Have a nice day", "nice"))

#Should return "Shhh, don't be so LOUD!"
print(highlight_word("Shhh, don't be so loud!", "loud"))

#Should return "Automating with Python is FUN"
print(highlight_word("Automating with Python is fun", "fun"))

# %% [markdown]
# # Contact
# Manuel Montoya Gamio
# * Correo: manuel.montoya@pucp.edu.pe
# * Telegram / Whatsapp: +51 907485569
