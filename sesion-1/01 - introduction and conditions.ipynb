# %% [markdown]
# # Python Inmersion Bootcamp
# Manuel Montoya Gamio | Machine Learning Engineer

# %% [markdown]
# Execute cells: `Ctrl + Enter` / `Shift + Enter`

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## Hello, world!

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ## Calculator

# %%
3*5
# Out:
# 15

# %%
10+20
# Out:
# 30

# %%
10/3
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Operators

# %% [markdown]
# `+ - * / ** // %`

# %%
3 ** 4
# Out:
# 81

# %% [markdown]
# integer division

# %%
10 / 6
# Out:
# 1.6666666666666667

# %%
10 // 6
# Out:
# 1

# %%
10 % 6
# Out:
# 4

# %%
10 + 5 * 15 + 2 ** 8
# Out:
# 341

# %% [markdown]
# string operations

# %%
"Hola" + "Manuel"
# Out:
# 'HolaManuel'

# %%
"Hola" * 3
# Out:
# 'HolaHolaHola'

# %%
"Hola" / 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 "Hola" / 5
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# ## Data types

# %% [markdown]
# `type`

# %%
type(3)
# Out:
# int

# %%
type(12.5)
# Out:
# float

# %%
type(10/3)
# Out:
# float

# %%
type("Joven Sensación")
# Out:
# str

# %% [markdown]
# ## Variables

# %% [markdown]
# <img src = 'https://i.redd.it/7delad5ecu821.jpg' width='400'>

# %%
a = 10
print(a)
type(a)
# Out:
# 10
# int

# %%
a = "Black Panther"
print(a)
type(a)
# Out:
# Black Panther
# str

# %% [markdown]
# assignment and expressions

# %%
a = 26+5*10
a
# Out:
# 76

# %% [markdown]
# Operator precedence
# * Parenthesis
# * Exponents
# * Multiplication / division
# * Addition / substraction

# %%
3*8/2
# Out:
# 12.0

# %%
type(5/5)
# Out:
# float

# %% [markdown]
# implicit and explicit casting

# %%
int(5/5)
# Out:
# 1

# %%
print("La nota aprobatoria del micromaster es " + str(70))
# Out:
# La nota aprobatoria del micromaster es 70

# %% [markdown]
# rules for variable names

# %% [markdown]
# Python es *case sensitive* `variable != Variable`

# %%
variable1 = 34

# %%
Variable1 = 45

# %%
variable1, Variable1
# Out:
# (34, 45)

# %%
variable_1 = "hola"

# %%
variable-1 = "hola"
# Out:
#   Cell In[37], line 1
#     variable-1 = "hola"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
12variable = "hola"
# Out:
#   Cell In[38], line 1
#     12variable = "hola"
#      ^
# SyntaxError: invalid decimal literal

# %%
_variable = "hola"

# %%
for = 45
# Out:
#   Cell In[45], line 1
#     for = 45
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# reserved keywords: https://www.programiz.com/python-programming/keyword-list

# %% [markdown]
# ## Functions

# %%
def saludo():
    print("Hola")
    print("Ciao")
    print("Hello")

print("Chau")
# Out:
# Chau

# %%
saludo()
# Out:
# Hola
# Ciao
# Hello

# %%
def decimal_part(a, b):
    return a/b - a//b

# %%
decimal_part(10, 3)
# Out:
# 0.3333333333333335

# %%
decimal = decimal_part(10, 3)

# %%
decimal
# Out:
# 0.3333333333333335

# %%
help(range)
# Out:
# Help on class range in module builtins:
#
# class range(object)
#  |  range(stop) -> range object
#  |  range(start, stop[, step]) -> range object
#  |
#  |  Return an object that produces a sequence of integers from start (inclusive)
#  |  to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
#  |  start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
#  |  These are exactly the valid indices for a list of 4 elements.
#  |  When step is given, it specifies the increment (or decrement).
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __reduce__(...)
#  |      Helper for pickle.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(...)
#  |      Return a reverse iterator.
#  |
#  |  count(...)
#  |      rangeobject.count(value) -> integer -- return number of occurrences of value
#  |
#  |  index(...)
#  |      rangeobject.index(value) -> integer -- return index of value.
#  |      Raise ValueError if the value is not present.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  start
#  |
#  |  step
#  |
#  |  stop

# %%
help(decimal_part)
# Out:
# Help on function decimal_part in module __main__:
#
# decimal_part(a, b)

# %% [markdown]
# docstring

# %%
def decimal_part(a: int, b: int) -> float:
    """This function returns the decimal part from dividing a / b

    Args:
        a (int): numerator
        b (int): denominator

    Returns:
        float: decimal part of a/b
    """
    
    return a/b - a//b

# %%
help(decimal_part)
# Out:
# Help on function decimal_part in module __main__:
#
# decimal_part(a: int, b: int) -> float
#     This function returns the decimal part from dividing a / b
#
#     Args:
#         a (int): numerator
#         b (int): denominator
#
#     Returns:
#         float: decimal part of a/b

# %% [markdown]
# variable scope

# %%
def decimal_part(a: int, b: int) -> float:

    resultado = a/b - a//b
    return resultado

# %%
decimal_part(10, 5)
# Out:
# 0.0

# %%
resultado
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 resultado
#
# NameError: name 'resultado' is not defined

# %% [markdown]
# `None`

# %%
None

# %%
type(None)
# Out:
# NoneType

# %%
def i_return_nothing():
    return

# %%
i_return_nothing()

# %%
type(i_return_nothing())
# Out:
# NoneType

# %%
None

# %%
def i_return_nothing():
    a = 5

# %%
type(i_return_nothing())
# Out:
# NoneType

# %% [markdown]
# unpacking values

# %%
def split_name(name):
    return name.split()

# %%
split_name("Karolina Giraldo")
# Out:
# ['Karolina', 'Giraldo']

# %%
split_name("Carlos Sainz Junior")
# Out:
# ['Carlos', 'Sainz', 'Junior']

# %%
a = split_name("Karolina Giraldo")
a
# Out:
# ['Karolina', 'Giraldo']

# %%
a, b = split_name("Karolina Giraldo Karol G")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 a, b = split_name("Karolina Giraldo Karol G")
#
# ValueError: too many values to unpack (expected 2)

# %%
def quotient_and_residual(a, b):
    
    return a//b, a%b

# %%
quotient_and_residual(10,3)
# Out:
# (3, 1)

# %%
a, b = quotient_and_residual(10, 3)

# %%
a
# Out:
# 3

# %%
b
# Out:
# 1

# %% [markdown]
# parametros por defecto

# %%
def power_to_n(b, n=2):

    return b**n

# %%
power_to_n(2, 10)
# Out:
# 1024

# %%
power_to_n(40)
# Out:
# 1600

# %%
power_to_n
# Out:
# <function __main__.power_to_n(b, n=2)>

# %%
type(power_to_n)
# Out:
# function

# %% [markdown]
# ## Comparing values

# %% [markdown]
# comparison operators: ```> < == !=```

# %%
3 < 4
# Out:
# True

# %%
4 < 1
# Out:
# False

# %%
5 == 10
# Out:
# False

# %%
5 = 10
# Out:
#   Cell In[124], line 1
#     5 = 10
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
5 != 10
# Out:
# True

# %% [markdown]
# boolean

# %%
type(True)
# Out:
# bool

# %% [markdown]
# logical operators: ```and or not```

# %%
(3 < 4) and (4 < 5)
# Out:
# True

# %%
(3 < 4) and (5 < 4)
# Out:
# False

# %%
(3 < 4) or (5 < 4)
# Out:
# True

# %%
not (3 < 4)
# Out:
# False

# %% [markdown]
# ```1 < "1"```

# %%
1 < "1"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 1 < "1"
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# 0 is False, everything else True

# %%
bool(10)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool("asdas")
# Out:
# True

# %%
bool(-1)
# Out:
# True

# %%
bool([])
# Out:
# False

# %% [markdown]
# ## Branching

# %%
a = "Pedro"

if len(a) > 10:
    print("Cadena Larga")
else:
    print("Cadena corta")
# Out:
# Cadena corta

# %%
a = 20

if a == 0:
    print("Cero")
elif a > 0:
    print("Positivo")
else:
    print("Negativo")
# Out:
# Positivo

# %%
assert True

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
def multiplicar(a, b=1):
    return a*b

# %%
assert multiplicar(5,2) == 10, 'Function multiplicar not well defined'
assert multiplicar(5,1) == 5, 'Function multiplicar not well defined for default parameters'

# %% [markdown]
# # Exercises 1

# %% [markdown]
# ## 1.1 Taylor Swift

# %% [markdown]
# Complete the script by filling in the missing parts. The function receives a name, then returns a greeting based on whether or not that name is "Taylor".

# %%
def greeting(name):
    
    if name == "Taylor":
        return "Welcome back Taylor!"
    
    return
    
assert greeting("Taylor") == "Welcome back Taylor!"
assert greeting("Rebecca") == None

# %% [markdown]
# ## 1.2 Seconds, minutes and hours
# Write a function that gets a number of seconds and returns the number of hours, minutes and seconds
#
# ```def convert_seconds(seconds)```
#
# convert_seconds(125) should return 0, 2, 5

# %%
def convert_seconds(seconds):
    
    hours = seconds // 3600
    minutes = (seconds % 3600) //60
    seconds = seconds - 60*minutes - 3600*hours
    
    return hours, minutes, seconds

assert convert_seconds(125) == (0,2,5)

# %% [markdown]
# ## 1.3 No pikachu

# %% [markdown]
# <img src="https://i.ytimg.com/vi/PL0NXNshCVQ/hq720.jpg?sqp=-oaymwEhCK4FEIIDSFryq4qpAxMIARUAAAAAGAElAADIQj0AgKJD&rs=AOn4CLAoAjmJ60ubsxxP3o6utJ33lJ9_-Q">

# %% [markdown]
# Write a function that chooses the best starter rival pokemon
#
#
# ```
# rival_pokemon("charmander") should return "squirtle"
# rival_pokemon("squirtle") should return "bulbasaur"
# rival_pokemon("bulbasaur") should return "charmander
# ```

# %%
def rival_pokemon(pokemon):
    
    if pokemon == "charmander":
        return "squirtle"
    elif pokemon == "squirtle":
        return "bulbasaur"
    elif pokemon == "bulbasaur":
        return "charmander"
    else:
        return ""
    
assert rival_pokemon("charmander") == "squirtle"
assert rival_pokemon("squirtle") == "bulbasaur"
assert rival_pokemon("bulbasaur") == "charmander"
assert rival_pokemon("pikachu") == ""

# %% [markdown]
# ## 1.4 the python way
# Create a script that switches the value of two variables a and b

# %%
a, b = 5, 10
a, b = b, a

a, b
# Out:
# (10, 5)

# %% [markdown]
# ## 1.5 Exam pass/fail
#
# Students in the micromaster receive their grades as Pass/Fail. Scores of 70 or more (out of 100) mean that the grade is "Pass". For lower scores, the grade is "Fail". In addition, scores above 95 are graded as "Top Score". Fill in this function so that it returns the proper grade.

# %%
def exam_grade(score):
    
    #your beautiful code here
    if score > 95:
        grade = "Top Score"
    
    elif score >= 70:
        grade = "Pass"
    
    else:
        grade = "Fail"
    
    return grade

assert exam_grade(75) == "Pass" 
assert exam_grade(55) == "Fail" 
assert exam_grade(70) == "Pass" 
assert exam_grade(95) == "Pass" 
assert exam_grade(100) == "Top Score"
assert exam_grade(0) == "Fail"

# %% [markdown]
# # 1.7 Longest word
# The longest_word function is used to compare 3 words. It should return the word with the most number of characters (and the first in the list when they have the same length). Fill in the blank to make this happen.

# %%
def longest_word(word1, word2, word3):
    if len(word1) >= len(word2) and len(word1) >= len(word3):
        word = word1
    elif len(word2) >= len(word1) and len(word2) >= len(word3):
        word = word2
    else:
        word = word3
    
    return(word)

assert longest_word("chair", "couch", "table") == "chair"
assert longest_word("bed", "bath", "beyond") == "beyond"
assert longest_word("laptop", "notebook", "desktop") == "notebook"

# %% [markdown]
# ## 1.8 Left padding
# An ecommerce company stores the serial number of client orders as integers. Since they are migrating to a new database they want to change the format to an eight digit string with leading zeros. That way, order 123 should become order 00000123, order 12345 should become order 00012345.
#
# Write a function that adds leading zeros to the store order numbers and returns a formated padded string

# %%
def lpadding(number):

    #your beautiful code here
    str_number = str(number)
    len_number = len(str_number)
    
    if len_number < 8:
        
        padded_string = '0'*(8 - len_number) + str_number
        return padded_string

    else:
        return str_number
    
        
assert lpadding(12345) == "00012345" 
assert lpadding(1234567) == "01234567"
assert lpadding(12345678) == "12345678"

# %% [markdown]
# ## 1.9 Name formatting
# Write a program that formats the first and last name of a given character according to the given parameters
#
# ```
# print(format_name("Ella", "Fitzgerald"))
# Name: Fitzgerald, Ella
#
#
# print(format_name("", "Einstein"))
# Name: Einstein
# ```

# %%
def format_name(first_name, last_name):
    
    # your beautiful code here
    string = "Name: "
    
    if len(last_name) + len(first_name) == 0:
        return ""
    elif len(last_name) > 0 and len(first_name) > 0:
        string += last_name + ', ' + first_name
    else:
        string += first_name + last_name
        
    return string 


assert format_name("Ernest", "Hemingway") == "Name: Hemingway, Ernest"
assert format_name("", "Madonna") == "Name: Madonna"
assert format_name("Voltaire", "") == "Name: Voltaire"
assert format_name("", "") == ""

# %% [markdown]
# ## 1.10 Number of blocks
# A filesystem has a block size of 4096 bytes. This means that a file of only 1 byte will use 1 block of 4096 bytes, a file of 4097 bytes will use 2 blocks of 4096 bytes. Complete the function to calculate the number of blocks that a file will use.

# %%
def calculate_storage(filesize):
    
    block_size = 4096
    
    full_blocks = filesize // block_size
    partial_block_remainder = filesize % block_size
    
    if partial_block_remainder == 0:
        
        return full_blocks * 4096
    
    return (full_blocks + 1) * 4096

assert calculate_storage(1) == 4096
assert calculate_storage(4096) == 4096
assert calculate_storage(4097) == 8192
assert calculate_storage(6000) == 8192

# %% [markdown]
# ## 1.11 Fractional part
# Write a function that returns the fractional part of a division (a number between 0 and 1). For example, if the numerator is 10 and the denominator is 3 it should return 0.333

# %%
def fractional_part(numerator, denominator):
    
    if denominator == 0:
        return 0
    
    return (numerator%denominator) / denominator


assert fractional_part(5, 5) == 0
assert fractional_part(5, 4) == 0.25
assert fractional_part(5, 2) == 0.5
assert fractional_part(5, 0) == 0
assert fractional_part(0, 5) == 0

# %% [markdown]
# ## 1.12 Secure password generator
#
# Use a Python script to generate a random password of 10 characters.
# Each time the program is run, a new password should be generated randomly.
#
# The password must contain:
# * 4 uppercase letters from A to Z,
# * 4 lowercase letters from a to z,
# * 2 digits from 0 to 9

# %%
import random

def shuffle(string):
    """this function shuffles the order of the characters of a given string"""

    tempList = list(string)
    random.shuffle(tempList)
    
    return ''.join(tempList)


def get_random_character(kind):
    
    if kind == 'lowercase':
        return chr(random.randint(ord('a'), ord('z')))
    elif kind == 'uppercase':
        return chr(random.randint(ord('A'), ord('Z')))
    elif kind == 'number':
        return chr(random.randint(ord('0'), ord('9')))
    else:
        return ''

def password_generator():

    lowercase_chars = 4
    uppercase_chars = 4
    number_chars = 2
    
    password = ''
    
    #your beautiful code here
    for _ in range(lowercase_chars):
        password += get_random_character('lowercase')
        
    for _ in range(uppercase_chars):
        password += get_random_character('uppercase')
        
    for _ in range(number_chars):
        password += get_random_character('number')
    
    password = shuffle(password)
    
    return password

# %% [markdown]
# ## Referencias
#
# * Python for everybody (Coursera): https://www.coursera.org/specializations/python
# * Python for everybody (book): https://www.py4e.com/book.php

# %% [markdown]
# ## Contact
#
# Manuel Montoya Gamio
# * Correo: manuel.montoya@pucp.edu.pe
# * Telegram / Whatsapp: +51 907485569
