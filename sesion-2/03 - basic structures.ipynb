# %% [markdown]
# # Python Inmersion Bootcamp - Basic Structures
# Manuel Montoya Gamio | Machine Learning Engineer

# %% [markdown]
# # Strings

# %%
cadena = 'te felicito que bien actuas'

# %%
cadena = "te felicito que bien actuas"

# %%
cadena = "don't you want me"

# %%
type(cadena)
# Out:
# str

# %% [markdown]
# single, double, triple quotes

# %%
cadena =  """Las estructuras de datos son
- cadenas
- listas
- tuplas"""

# %%
cadena
# Out:
# 'Las estructuras de datos son\n- cadenas\n- listas\n- tuplas'

# %%
print(cadena)
# Out:
# Las estructuras de datos son
# - cadenas
# - listas
# - tuplas

# %% [markdown]
# concatenating

# %%
"te" + " felicito" + " que" + " bien"
# Out:
# 'te felicito que bien'

# %% [markdown]
# `len`

# %%
cadena = "te felicito que bien actuas"

# %%
len(cadena)
# Out:
# 27

# %% [markdown]
# iterate over a string (?)

# %%
for numero in [10, 20, 30]:
    print(numero)
# Out:
# 10
# 20
# 30

# %%
for letra in "Shakira":
    print(letra)
# Out:
# S
# h
# a
# k
# i
# r
# a

# %% [markdown]
# indexing: positive and negative indexes

# %%
cadena = "Pedro Pascal"

# %%
cadena[0]
# Out:
# 'P'

# %%
cadena[1]
# Out:
# 'e'

# %%
cadena[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 cadena[100]
#
# IndexError: string index out of range

# %%
cadena
# Out:
# 'Pedro Pascal'

# %%
cadena[-1]
# Out:
# 'l'

# %%
cadena[-3]
# Out:
# 'c'

# %% [markdown]
# slicing

# %%
cadena
# Out:
# 'Pedro Pascal'

# %%
cadena[0:5] # -> indices: 0, 1, 2, 3, 4
# Out:
# 'Pedro'

# %%
cadena
# Out:
# 'Pedro Pascal'

# %%
cadena[0:10:2]
# Out:
# 'PdoPs'

# %% [markdown]
# inmutability

# %%
cadena = "a kong string with a silly typo"

# %%
cadena[2] = "l"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 cadena[2] = "l"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# index

# %%
cadena = "a long string with a silly typo"

# %%
cadena.index("w")
# Out:
# 14

# %%
cadena.index("string")
# Out:
# 7

# %%
cadena = "a kong string with a silly typo"

# %%
indice = cadena.index("k")
cadena[:indice] + "l" + cadena[indice +1:]
# Out:
# 'a long string with a silly typo'

# %%
cadena[:]
# Out:
# 'a kong string with a silly typo'

# %% [markdown]
# in

# %%
poppins = "supercalifragilisticexpialidocious"

# %%
"x" in poppins
# Out:
# True

# %%
poppins.index("x")
# Out:
# 21

# %% [markdown]
# methods
#
# * upper, lower
# * strip
# * count
# * startswith, endswith
# * isnumeric
# * split, join
#
# String methods: https://www.w3schools.com/python/python_ref_string.asp

# %%
cadena = "Me gustan los legos de Lego Marvel"

# %%
cadena.upper()
# Out:
# 'ME GUSTAN LOS LEGOS DE LEGO MARVEL'

# %%
cadena.lower()
# Out:
# 'me gustan los legos de lego marvel'

# %%
cadena.split()
# Out:
# ['Me', 'gustan', 'los', 'legos', 'de', 'Lego', 'Marvel']

# %%
cadena = "     Me gustan los legos de Lego Marvel    "

# %%
cadena.lstrip()
# Out:
# 'Me gustan los legos de Lego Marvel    '

# %%
cadena.rstrip()
# Out:
# '     Me gustan los legos de Lego Marvel'

# %%
cadena.strip()
# Out:
# 'Me gustan los legos de Lego Marvel'

# %%
cadena.replace("legos", "LEGOS").strip()
# Out:
# 'Me gustan los LEGOS de Lego Marvel'

# %%
lista = ['Me', 'gustan', 'los', 'legos', 'de', 'Lego', 'Marvel']

" ".join(lista)
# Out:
# 'Me gustan los legos de Lego Marvel'

# %%
"    ".join(lista)
# Out:
# 'Me    gustan    los    legos    de    Lego    Marvel'

# %%
cadena = "     Me gustan     los    legos   de     Lego Marvel    "

def fix_string(cadena):
    """deletes extra spaces in a string"""

    return " ".join(cadena.split())

fix_string(cadena)
# Out:
# 'Me gustan los legos de Lego Marvel'

# %% [markdown]
# f strings

# %%
distancia = 25

"La distancia es " + str(distancia)
# Out:
# 'La distancia es 25'

# %%
f"La distancia es {distancia}"
# Out:
# 'La distancia es 25'

# %%
f"La distancia ida y vuelta es {2*distancia}"
# Out:
# 'La distancia ida y vuelta es 50'

# %% [markdown]
# f string formatting

# %%
distancia = 12.12312312
f"La distancia ida y vuelta es {distancia}"
# Out:
# 'La distancia ida y vuelta es 12.12312312'

# %%
distancia = 12.12312312
f"La distancia ida y vuelta es {distancia:2.2f}"
# Out:
# 'La distancia ida y vuelta es 12.12'

# %% [markdown]
# ## Exercises

# %% [markdown]
# Write a function that checks if a string is palindrome

# %%
#hint: you can reverse a string and check if the reversed string is the same as the original one
def is_palindrome(input_string):
    clean_string = input_string.replace(" ","").lower()
    return clean_string[::-1]==clean_string

assert is_palindrome("kayak")
assert is_palindrome("Never Odd or Even")
assert not is_palindrome("Never say never")

# %% [markdown]
# Write a function that replaces the old domain of input emails for a new one. If the email does not belong to the old domain, the function should not modify it

# %%
def replace_domain(email, old_domain, new_domain):    
    
    return 
    
    
assert replace_domain('pikachu@pokemon.com', 'pokemon.com', 'pokemon.pe') == "pikachu@pokemon.pe"
assert replace_domain('pikachu@breit.com', 'pokemon.com', 'pokemon.edu') == "pikachu@breit.com"
# Out:
# None
# None

# %% [markdown]
# Write a function that prints the nametag of the first and last name parameters

# %%
def nametag(first_name, last_name):
    
    return ""

assert nametag("Jane", "Smith") == "Jane S."
assert nametag("Francesco", "Rinaldi") == "Francesco R."
assert nametag("Jean-Luc", "Grand-Pierre") == "Jean-Luc G."

# %% [markdown]
# Solve the minion game: https://www.hackerrank.com/challenges/the-minion-game/problem?isFullScreen=true

# %% [markdown]
# ## Challenge

# %% [markdown]
# Translate the enigma

# %% [markdown]
# g fmnc wms bgblr rpylqjyrc gr zw fylb. rfyrq ufyr amknsrcpq ypc dmp. bmgle gr gl zw fylb gq glcddgagclr ylb rfyr'q ufw rfgq rcvr gq qm jmle

# %% [markdown]
# <img src='http://www.pythonchallenge.com/pc/def/map.jpg' width = 400 align='left'>

# %% [markdown]
# # Lists

# %%
friends = ["Gabriela", "Patricia", "Nicole", "Sofia"]
friends
# Out:
# ['Gabriela', 'Patricia', 'Nicole', 'Sofia']

# %%
type(friends)
# Out:
# list

# %%
friends[1]
# Out:
# 'Patricia'

# %% [markdown]
# len, in

# %%
len(friends)
# Out:
# 4

# %%
lista = ["Gabriela", 12312, 123.1, [1,2,3,4,5]]
lista
# Out:
# ['Gabriela', 12312, 123.1, [1, 2, 3, 4, 5]]

# %%
"Gabriela" in lista
# Out:
# True

# %% [markdown]
# indexing, slicing

# %%
friends
# Out:
# ['Gabriela', 'Patricia', 'Nicole', 'Sofia']

# %%
friends[:3]
# Out:
# ['Gabriela', 'Patricia', 'Nicole']

# %%
friends[-1]
# Out:
# 'Sofia'

# %% [markdown]
# modify a list

# %%
friends
# Out:
# ['Gabriela', 'Patricia', 'Nicole', 'Sofia']

# %%
friends[2] = "Nicolle"

# %%
friends
# Out:
# ['Gabriela', 'Patricia', 'Nicolle', 'Sofia']

# %% [markdown]
# append, insert, remove

# %%
friends
# Out:
# ['Gabriela', 'Patricia', 'Nicolle', 'Sofia']

# %%
friends + ["Elena"]
# Out:
# ['Gabriela', 'Patricia', 'Nicolle', 'Sofia', 'Elena']

# %%
friends.append("Elena")

# %%
friends
# Out:
# ['Gabriela', 'Patricia', 'Nicolle', 'Sofia', 'Elena']

# %%
friends.index('Patricia')
# Out:
# 1

# %%
friends.insert(2, "Monica")

# %%
friends
# Out:
# ['Gabriela', 'Patricia', 'Monica', 'Nicolle', 'Sofia', 'Elena']

# %%
friends.sort()

# %%
friends
# Out:
# ['Elena', 'Gabriela', 'Monica', 'Nicolle', 'Patricia', 'Sofia']

# %% [markdown]
# ## Tuples

# %%
def convert_seconds(seconds):
    
    hours = seconds // 3600
    minutes = (seconds - hours*3600) // 60
    remaining_seconds = seconds - hours*3600 - minutes * 60
    
    return hours, minutes, remaining_seconds

convert_seconds(10000)
# Out:
# (2, 46, 40)

# %%
hours, minutes, seconds = convert_seconds(100000)

# %%
type(convert_seconds(10000))
# Out:
# tuple

# %%
tupla = (10,20, 30, 40)
tupla
# Out:
# (10, 20, 30, 40)

# %%
tupla[3]
# Out:
# 40

# %%
tupla[-1]
# Out:
# 40

# %%
tupla[:3]
# Out:
# (10, 20, 30)

# %%
tupla[2] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 tupla[2] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
tupla = (10,20, [1,2,2,], "hola")
tupla
# Out:
# (10, 20, [1, 2, 2], 'hola')

# %% [markdown]
# ## Iterate over lists

# %%
friends = ['Gabriela', 'Monica', 'Nicolle', 'Patricia']

for friend in friends:
    print(friend)
# Out:
# Gabriela
# Monica
# Nicolle
# Patricia

# %% [markdown]
# Calculate the total number of characters and the average number of characters of a list of names

# %%
friends = ['Gabriela', 'Patricia', 'Nicolle', 'Sofia']

total = 0

for friend in friends:
    total += len(friend)

average = total / len(friends)
total, average
# Out:
# (28, 7.0)

# %% [markdown]
# Write a function that generates the email adresses of employees using the format name_lastname@domain

# %%
domain = 'breit.pe'
employees = [('Manuel', 'Montoya'), ('Rebeca', 'Gomez'), ('Carolina', 'Giraldo'), ('Valentin', 'Oliva')]

# %%
for employee in employees:
    
    email = employee[0] + "_" +employee[1] + "@" + domain
    print(email.lower())
# Out:
# manuel_montoya@breit.pe
# rebeca_gomez@breit.pe
# carolina_giraldo@breit.pe
# valentin_oliva@breit.pe

# %%
for employee in employees:
    
    name = employee[0].lower()
    last_name = employee[1].lower()

    email = f"{name}_{last_name}@{domain}"
    print(email)
# Out:
# manuel_montoya@breit.pe
# rebeca_gomez@breit.pe
# carolina_giraldo@breit.pe
# valentin_oliva@breit.pe

# %% [markdown]
# For a list of names, calculate the ratio between the length of the name and the index of the name (starting with 1)

# %%
friends = ['Gabriela', 'Patricia', 'Nicolle', 'Sofia']

for index, friend in enumerate(friends):
    print(len(friend) / (index + 1))
# Out:
# 8.0
# 4.0
# 2.3333333333333335
# 1.25

# %% [markdown]
# list comprehension

# %% [markdown]
# create a list of the first 10 square numbers

# %%
lista = []

for number in range(1, 11):
    lista.append(number**2)

lista
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
[number**2 for number in range(1,11)]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
friends = ['Gabriela', 'Patricia', 'Nicolle', 'Sofia']

[f"{friend}@breit.pe" for friend in friends]
# Out:
# ['Gabriela@breit.pe',
#  'Patricia@breit.pe',
#  'Nicolle@breit.pe',
#  'Sofia@breit.pe']

# %% [markdown]
# Write a function that returns a list of the divisors of a given number

# %%
def divisor(n):

    return [d for d in range(1, n+1) if n%d==0]

divisor(10)
# Out:
# [1, 2, 5, 10]

# %% [markdown]
# ## Exercises

# %% [markdown]
# Write a function that returns the nth word of a sentence (n is positive)

# %%
def get_nth_word(sentence, n):
    
    return ""



assert get_nth_word("muchachos ahora nos volvimos a ilusionar", 4) == "volvimos"

assert get_nth_word("muchachos ahora nos volvimos a ilusionar", 10) == ""

# %% [markdown]
# Write a function that changes the extension of .csv files to .txt

# %%
def change_csv_to_txt(filenames):
    
    return []


assert change_csv_to_txt(['file1.txt', 'file2.csv', 'file3.xlsx', 'file4.csv', 'file5.ppt']) == ['file1.txt', 'file2.txt', 'file3.xlsx', 'file4.txt', 'file5.ppt']
# Out:
# []

# %% [markdown]
# Write a function that turns text into pig latin: a simple text transformation that modifies each word moving the first character to the end and appending "ay" to the end. For example, python ends up as ythonpay

# %%
def pig_latin(text):

    return ""
    
assert pig_latin("hello how are you") == "ellohay owhay reaay ouyay"
assert pig_latin("programming in python is fun") == "rogrammingpay niay ythonpay siay unfay"

# %% [markdown]
# Use a list comprehension to create a list of squared numbers (n*n). The function receives the variables start and end, and returns a list of squares of consecutive numbers between start and end inclusively.
# For example, squares(2, 3) should return [4, 9].

# %%
def squares(start, end):
    return []

print(squares(2, 3)) # Should be [4, 9]
print(squares(1, 5)) # Should be [1, 4, 9, 16, 25]
print(squares(0, 10)) # Should be [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# ## Challenge

# %% [markdown]
# The permissions of a file in a Linux system are split into three sets of three permissions: read, write, and execute for the owner, group, and others.
#
# Each of the three values can be expressed as an octal number summing each permission, with 4 corresponding to read, 2 to write, and 1 to execute. Or it can be written with a string using the letters r, w, and x or - when the permission is not granted.
#
# For example:
# * 640 is read/write for the owner, read for the group, and no permissions for the others; converted to a string, it would be: "rw-r-----"
# * 755 is read/write/execute for the owner, and read/execute for group and others; converted to a string, it would be: "rwxr-xr-x"
#
# Write a function that converts a permission octal into a string format

# %%
def octal_to_string(octal):
    
    result = ""
    value_letters = [(4,"r"),(2,"w"),(1,"x")]
    
    # Iterate over each of the digits in octal
    for number in [int(n) for n in str(octal)]:
        
        # each number should be translated into permissions rwx
        # 7 in binary is 111 -> rwx
        # 5 in binary is 101 -> r-x
        
        for value, letter in value_letters:

            pass            
            
    return 

print(octal_to_string(777)) # Should be rwxrwxrwx
print(octal_to_string(755)) # Should be rwxr-xr-x
print(octal_to_string(644)) # Should be rw-r--r--
print(octal_to_string(750)) # Should be rwxr-x---
print(octal_to_string(600)) # Should be rw-------
# Out:
# rwxrwxrwx
# rwxr-xr-x
# rw-r--r--
# rwxr-x---
# rw-------
# ---

# %% [markdown]
# # Contact
# Manuel Montoya Gamio
# * Correo: manuel.montoya@pucp.edu.pe
# * Telegram / Whatsapp: +51 907485569
